# %% [markdown]
# ## **Importing Required Libraries**

# %%
# Import libraries for data manipulation, visualization, and machine learning
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import SGD, Adam, Adagrad, RMSprop
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from collections import Counter
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Loading the Data**

# %%
# Load the Telco Customer Churn dataset
data = pd.read_excel('/kaggle/input/telco-customer-churn-ibm-dataset/Telco_customer_churn.xlsx')
data.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
#   Paperless Billing             Payment Method  Monthly Charges Total Charges  \
# 0               Yes               Mailed check            53.85        108.15
# 1               Yes           Electronic check            70.70        151.65
# 2               Yes           Electronic check            99.65         820.5
# 3               Yes           Electronic check           104.80       3046.05
# 4               Yes  Bank transfer (automatic)           103.70        5036.3
#
#   Churn Label Churn Value Churn Score  CLTV                   Churn Reason
# 0         Yes           1          86  3239   Competitor made better offer
# 1         Yes           1          67  2701                          Moved
# 2         Yes           1          86  5372                          Moved
# 3         Yes           1          84  5003                          Moved
# 4         Yes           1          89  5340  Competitor had better devices
#
# [5 rows x 33 columns]

# %% [markdown]
# ## **EDA**

# %%
# Define a function to get data structure, types, unique values, and nulls for each column
def data_info(data):
    cols = []
    unique_val = []
    n_uniques = []
    dtypes = []
    nulls = []
    for col in data.columns:
        cols.append(col)
        dtypes.append(data[col].dtype)
        n_uniques.append(data[col].nunique())
        unique_val.append(data[col].unique())
        nulls.append(data[col].isna().sum())
        
    return pd.DataFrame({
        "Column": cols,
        "Data Type": dtypes,
        "Unique Values Count": n_uniques,
        "Unique Values": unique_val,
        "Null Count": nulls
    })

# Display dataset information
data_info(data)
# Out:
#                Column Data Type  Unique Values Count  \
# 0          CustomerID    object                 7043
# 1               Count     int64                    1
# 2             Country    object                    1
# 3               State    object                    1
# 4                City    object                 1129
# 5            Zip Code     int64                 1652
# 6            Lat Long    object                 1652
# 7            Latitude   float64                 1652
# 8           Longitude   float64                 1651
# 9              Gender    object                    2
# 10     Senior Citizen    object                    2
# 11            Partner    object                    2
# 12         Dependents    object                    2
# 13      Tenure Months     int64                   73
# 14      Phone Service    object                    2
# 15     Multiple Lines    object                    3
# 16   Internet Service    object                    3
# 17    Online Security    object                    3
# 18      Online Backup    object                    3
# 19  Device Protection    object                    3
# 20       Tech Support    object                    3
# 21       Streaming TV    object                    3
# 22   Streaming Movies    object                    3
# 23           Contract    object                    3
# 24  Paperless Billing    object                    2
# 25     Payment Method    object                    4
# 26    Monthly Charges   float64                 1585
# 27      Total Charges    object                 6531
# 28        Churn Label    object                    2
# 29        Churn Value     int64                    2
# 30        Churn Score     int64                   85
# 31               CLTV     int64                 3438
# 32       Churn Reason    object                   20
#
#                                         Unique Values  Null Count
# 0   [3668-QPYBK, 9237-HQITU, 9305-CDSKC, 7892-POOK...           0
# 1                                                 [1]           0
# 2                                     [United States]           0
# 3                                        [California]           0
# 4   [Los Angeles, Beverly Hills, Huntington Park, ...           0
# 5   [90003, 90005, 90006, 90010, 90015, 90020, 900...           0
# 6   [33.964131, -118.272783, 34.059281, -118.30742...           0
# 7   [33.964131, 34.059281, 34.048013, 34.062125, 3...           0
# 8   [-118.272783, -118.30742, -118.293953, -118.31...           0
# 9                                      [Male, Female]           0
# 10                                          [No, Yes]           0
# 11                                          [No, Yes]           0
# 12                                          [No, Yes]           0
# 13  [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...           0
# 14                                          [Yes, No]           0
# 15                        [No, Yes, No phone service]           0
# 16                             [DSL, Fiber optic, No]           0
# 17                     [Yes, No, No internet service]           0
# 18                     [Yes, No, No internet service]           0
# 19                     [No, Yes, No internet service]           0
# 20                     [No, Yes, No internet service]           0
# 21                     [No, Yes, No internet service]           0
# 22                     [No, Yes, No internet service]           0
# 23               [Month-to-month, Two year, One year]           0
# 24                                          [Yes, No]           0
# 25  [Mailed check, Electronic check, Bank transfer...           0
# 26  [53.85, 70.7, 99.65, 104.8, 103.7, 55.2, 39.65...           0
# 27  [108.15, 151.65, 820.5, 3046.05, 5036.3, 528.3...           0
# 28                                          [Yes, No]           0
# 29                                             [1, 0]           0
# 30  [86, 67, 84, 89, 78, 100, 92, 77, 97, 74, 66, ...           0
# 31  [3239, 2701, 5372, 5003, 5340, 5925, 5433, 483...           0
# 32  [Competitor made better offer, Moved, Competit...        5174

# %%
# Drop columns that are not relevant for analysis
data.drop(['CustomerID', 'Churn Label', 'Count', 'Country', 'State', 'Zip Code', 'Lat Long', 'City'], axis=1, inplace=True)

# %%
data.head()
# Out:
#     Latitude   Longitude  Gender Senior Citizen Partner Dependents  \
# 0  33.964131 -118.272783    Male             No      No         No
# 1  34.059281 -118.307420  Female             No      No        Yes
# 2  34.048013 -118.293953  Female             No      No        Yes
# 3  34.062125 -118.315709  Female             No     Yes        Yes
# 4  34.039224 -118.266293    Male             No      No        Yes
#
#    Tenure Months Phone Service Multiple Lines Internet Service  ...  \
# 0              2           Yes             No              DSL  ...
# 1              2           Yes             No      Fiber optic  ...
# 2              8           Yes            Yes      Fiber optic  ...
# 3             28           Yes            Yes      Fiber optic  ...
# 4             49           Yes            Yes      Fiber optic  ...
#
#   Streaming Movies        Contract Paperless Billing  \
# 0               No  Month-to-month               Yes
# 1               No  Month-to-month               Yes
# 2              Yes  Month-to-month               Yes
# 3              Yes  Month-to-month               Yes
# 4              Yes  Month-to-month               Yes
#
#               Payment Method Monthly Charges Total Charges Churn Value  \
# 0               Mailed check           53.85        108.15           1
# 1           Electronic check           70.70        151.65           1
# 2           Electronic check           99.65         820.5           1
# 3           Electronic check          104.80       3046.05           1
# 4  Bank transfer (automatic)          103.70        5036.3           1
#
#   Churn Score  CLTV                   Churn Reason
# 0          86  3239   Competitor made better offer
# 1          67  2701                          Moved
# 2          86  5372                          Moved
# 3          84  5003                          Moved
# 4          89  5340  Competitor had better devices
#
# [5 rows x 25 columns]

# %%
le=LabelEncoder()
data['Contract']=le.fit_transform(data['Contract'])

# %%
data['Churn Value'].value_counts()
# Out:
# Churn Value
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
data['Churn Reason'].value_counts()
# Out:
# Churn Reason
# Attitude of support person                   192
# Competitor offered higher download speeds    189
# Competitor offered more data                 162
# Don't know                                   154
# Competitor made better offer                 140
# Attitude of service provider                 135
# Competitor had better devices                130
# Network reliability                          103
# Product dissatisfaction                      102
# Price too high                                98
# Service dissatisfaction                       89
# Lack of self-service on Website               88
# Extra data charges                            57
# Moved                                         53
# Lack of affordable download/upload speed      44
# Limited range of services                     44
# Long distance charges                         44
# Poor expertise of phone support               20
# Poor expertise of online support              19
# Deceased                                       6
# Name: count, dtype: int64

# %%
data['Churn Reason'].fillna("not leave",inplace=True)

# %%
data['Total Charges']=pd.to_numeric(data['Total Charges'],errors='coerce')

# %%
data['Total Charges'].isna().sum()
# Out:
# 11

# %%
data['Total Charges'].fillna(data['Total Charges'].mean(),inplace=True)

# %%
data_info(data)
# Out:
#                Column Data Type  Unique Values Count  \
# 0            Latitude   float64                 1652
# 1           Longitude   float64                 1651
# 2              Gender    object                    2
# 3      Senior Citizen    object                    2
# 4             Partner    object                    2
# 5          Dependents    object                    2
# 6       Tenure Months     int64                   73
# 7       Phone Service    object                    2
# 8      Multiple Lines    object                    3
# 9    Internet Service    object                    3
# 10    Online Security    object                    3
# 11      Online Backup    object                    3
# 12  Device Protection    object                    3
# 13       Tech Support    object                    3
# 14       Streaming TV    object                    3
# 15   Streaming Movies    object                    3
# 16           Contract     int64                    3
# 17  Paperless Billing    object                    2
# 18     Payment Method    object                    4
# 19    Monthly Charges   float64                 1585
# 20      Total Charges   float64                 6531
# 21        Churn Value     int64                    2
# 22        Churn Score     int64                   85
# 23               CLTV     int64                 3438
# 24       Churn Reason    object                   21
#
#                                         Unique Values  Null Count
# 0   [33.964131, 34.059281, 34.048013, 34.062125, 3...           0
# 1   [-118.272783, -118.30742, -118.293953, -118.31...           0
# 2                                      [Male, Female]           0
# 3                                           [No, Yes]           0
# 4                                           [No, Yes]           0
# 5                                           [No, Yes]           0
# 6   [2, 8, 28, 49, 10, 1, 47, 17, 5, 34, 11, 15, 1...           0
# 7                                           [Yes, No]           0
# 8                         [No, Yes, No phone service]           0
# 9                              [DSL, Fiber optic, No]           0
# 10                     [Yes, No, No internet service]           0
# 11                     [Yes, No, No internet service]           0
# 12                     [No, Yes, No internet service]           0
# 13                     [No, Yes, No internet service]           0
# 14                     [No, Yes, No internet service]           0
# 15                     [No, Yes, No internet service]           0
# 16                                          [0, 2, 1]           0
# 17                                          [Yes, No]           0
# 18  [Mailed check, Electronic check, Bank transfer...           0
# 19  [53.85, 70.7, 99.65, 104.8, 103.7, 55.2, 39.65...           0
# 20  [108.15, 151.65, 820.5, 3046.05, 5036.3, 528.3...           0
# 21                                             [1, 0]           0
# 22  [86, 67, 84, 89, 78, 100, 92, 77, 97, 74, 66, ...           0
# 23  [3239, 2701, 5372, 5003, 5340, 5925, 5433, 483...           0
# 24  [Competitor made better offer, Moved, Competit...           0

# %%
data=pd.get_dummies(data,drop_first=True)
data.head()
# Out:
#     Latitude   Longitude  Tenure Months  Contract  Monthly Charges  \
# 0  33.964131 -118.272783              2         0            53.85
# 1  34.059281 -118.307420              2         0            70.70
# 2  34.048013 -118.293953              8         0            99.65
# 3  34.062125 -118.315709             28         0           104.80
# 4  34.039224 -118.266293             49         0           103.70
#
#    Total Charges  Churn Value  Churn Score  CLTV  Gender_Male  ...  \
# 0         108.15            1           86  3239         True  ...
# 1         151.65            1           67  2701        False  ...
# 2         820.50            1           86  5372        False  ...
# 3        3046.05            1           84  5003        False  ...
# 4        5036.30            1           89  5340         True  ...
#
#    Churn Reason_Limited range of services  Churn Reason_Long distance charges  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
# 3                                   False                               False
# 4                                   False                               False
#
#    Churn Reason_Moved  Churn Reason_Network reliability  \
# 0               False                             False
# 1                True                             False
# 2                True                             False
# 3                True                             False
# 4               False                             False
#
#    Churn Reason_Poor expertise of online support  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Churn Reason_Poor expertise of phone support  Churn Reason_Price too high  \
# 0                                         False                        False
# 1                                         False                        False
# 2                                         False                        False
# 3                                         False                        False
# 4                                         False                        False
#
#    Churn Reason_Product dissatisfaction  Churn Reason_Service dissatisfaction  \
# 0                                 False                                 False
# 1                                 False                                 False
# 2                                 False                                 False
# 3                                 False                                 False
# 4                                 False                                 False
#
#    Churn Reason_not leave
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
#
# [5 rows x 54 columns]

# %%
X=data.drop(['Churn Value'],axis=1).values
y=data['Churn Value'].values

# %%
ros = SMOTE(random_state=42)
X,y = ros.fit_resample(X, y)
Counter(y)
# Out:
# Counter({1: 5174, 0: 5174})

# %%
train_X,test_X,train_y,test_y=train_test_split(X,y,test_size=0.2)

# %%
#fearture scaling 
sd=StandardScaler()
train_X=sd.fit_transform(train_X)
test_X=sd.transform(test_X)

# %% [markdown]
# ## Model

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',   
    patience=10,           
    restore_best_weights=True 
)

def build_model():
    model = Sequential([
        Dense(64, activation='relu', input_shape=(train_X.shape[1],)),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    return model

# %%
optimizer_types = ['adam', 'sgd', 'adagrad', 'rmsprop']

def get_optimizer(optimizer_type):
    if optimizer_type == 'adam':
        return Adam(learning_rate=lr_schedule, beta_1=0.9, beta_2=0.99)
    elif optimizer_type == 'sgd':
        return SGD(learning_rate=lr_schedule)
    elif optimizer_type == 'adagrad':
        return Adagrad(learning_rate=lr_schedule)
    else:
        return RMSprop(learning_rate=lr_schedule)

# %%
initial_learning_rate = 0.001
lr_schedule = ExponentialDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True
)

# %%
for opt_type in optimizer_types:
    print(f"\nTraining with optimizer: {opt_type}")
    
    # Build a new model for each optimizer
    model = build_model()
    
    # Compile model with the current optimizer
    opt = get_optimizer(opt_type)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    # Fresh early stopping callback for each optimizer
    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    
    # Train the model
    history = model.fit(train_X, train_y, validation_split=0.1, batch_size=128, epochs=15, callbacks=[early_stopping])
    
    # Plot accuracy
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.legend()
    plt.title(f'Model Accuracy - {opt_type}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.show()
    
    # Plot loss
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.legend()
    plt.title(f'Model Loss - {opt_type}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.show()
    
    # Predict and evaluate
    y_pred = model.predict(test_X)
    y_p = [1 if i > 0.5 else 0 for i in y_pred]
    
    # Evaluate model
    accuracy = model.evaluate(test_X, test_y)[1]
    print(f'Test Accuracy with {opt_type}: {accuracy:.2f}')
    print(classification_report(test_y, y_p))
    
    # Confusion matrix
    cm = confusion_matrix(test_y, y_p)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix - {opt_type}')
    plt.ylabel('Actual labels')
    plt.xlabel('Predicted labels')
    plt.show()
# Out:
# Training with optimizer: adam
# Epoch 1/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.7843 - loss: 0.4812 - val_accuracy: 0.9722 - val_loss: 0.1120
# Epoch 2/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9919 - loss: 0.0665 - val_accuracy: 0.9964 - val_loss: 0.0232
# Epoch 3/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9989 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 4/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9996 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 5/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 6/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 7/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.1256e-04 - val_accuracy: 1.0000 - val_loss: 8.9813e-04
# Epoch 8/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.5569e-04 - val_accuracy: 1.0000 - val_loss: 5.7365e-04
# Epoch 9/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.0935e-04 - val_accuracy: 1.0000 - val_loss: 3.7288e-04
# Epoch 10/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.2220e-04 - val_accuracy: 1.0000 - val_loss: 2.5425e-04
# Epoch 11/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.3307e-04 - val_accuracy: 1.0000 - val_loss: 1.7121e-04
# Epoch 12/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.9877e-05 - val_accuracy: 1.0000 - val_loss: 1.2031e-04
# Epoch 13/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.2017e-05 - val_accuracy: 1.0000 - val_loss: 8.6163e-05
# Epoch 14/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.8355e-05 - val_accuracy: 1.0000 - val_loss: 5.6097e-05
# Epoch 15/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.7536e-05 - val_accuracy: 1.0000 - val_loss: 4.0645e-05
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.4506e-05
# Test Accuracy with adam: 1.00
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1011
#            1       1.00      1.00      1.00      1059
#
#     accuracy                           1.00      2070
#    macro avg       1.00      1.00      1.00      2070
# weighted avg       1.00      1.00      1.00      2070
# Training with optimizer: sgd
# Epoch 1/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4896 - loss: 0.7424 - val_accuracy: 0.5290 - val_loss: 0.7150
# Epoch 2/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5434 - loss: 0.7070 - val_accuracy: 0.5785 - val_loss: 0.6864
# Epoch 3/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5744 - loss: 0.6781 - val_accuracy: 0.6111 - val_loss: 0.6609
# Epoch 4/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6078 - loss: 0.6590 - val_accuracy: 0.6365 - val_loss: 0.6380
# Epoch 5/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6436 - loss: 0.6334 - val_accuracy: 0.6643 - val_loss: 0.6168
# Epoch 6/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6745 - loss: 0.6127 - val_accuracy: 0.6824 - val_loss: 0.5971
# Epoch 7/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7084 - loss: 0.5919 - val_accuracy: 0.7150 - val_loss: 0.5787
# Epoch 8/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7258 - loss: 0.5761 - val_accuracy: 0.7476 - val_loss: 0.5613
# Epoch 9/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7586 - loss: 0.5524 - val_accuracy: 0.7705 - val_loss: 0.5448
# Epoch 10/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7793 - loss: 0.5349 - val_accuracy: 0.7862 - val_loss: 0.5291
# Epoch 11/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7863 - loss: 0.5251 - val_accuracy: 0.8031 - val_loss: 0.5141
# Epoch 12/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8136 - loss: 0.5022 - val_accuracy: 0.8152 - val_loss: 0.4997
# Epoch 13/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8132 - loss: 0.4953 - val_accuracy: 0.8285 - val_loss: 0.4858
# Epoch 14/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8267 - loss: 0.4799 - val_accuracy: 0.8357 - val_loss: 0.4724
# Epoch 15/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8428 - loss: 0.4616 - val_accuracy: 0.8478 - val_loss: 0.4595
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8561 - loss: 0.4534
# Test Accuracy with sgd: 0.86
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1011
#            1       0.84      0.90      0.87      1059
#
#     accuracy                           0.86      2070
#    macro avg       0.86      0.86      0.86      2070
# weighted avg       0.86      0.86      0.86      2070
# Training with optimizer: adagrad
# Epoch 1/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4492 - loss: 0.7865 - val_accuracy: 0.5676 - val_loss: 0.7028
# Epoch 2/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5630 - loss: 0.6993 - val_accuracy: 0.6401 - val_loss: 0.6438
# Epoch 3/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6501 - loss: 0.6408 - val_accuracy: 0.7077 - val_loss: 0.5997
# Epoch 4/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7248 - loss: 0.5957 - val_accuracy: 0.7524 - val_loss: 0.5642
# Epoch 5/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7644 - loss: 0.5615 - val_accuracy: 0.7959 - val_loss: 0.5341
# Epoch 6/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7932 - loss: 0.5311 - val_accuracy: 0.8128 - val_loss: 0.5077
# Epoch 7/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8152 - loss: 0.5036 - val_accuracy: 0.8261 - val_loss: 0.4840
# Epoch 8/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8273 - loss: 0.4827 - val_accuracy: 0.8430 - val_loss: 0.4626
# Epoch 9/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8533 - loss: 0.4561 - val_accuracy: 0.8527 - val_loss: 0.4430
# Epoch 10/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8648 - loss: 0.4362 - val_accuracy: 0.8647 - val_loss: 0.4247
# Epoch 11/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8695 - loss: 0.4216 - val_accuracy: 0.8708 - val_loss: 0.4077
# Epoch 12/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8849 - loss: 0.4034 - val_accuracy: 0.8841 - val_loss: 0.3916
# Epoch 13/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8924 - loss: 0.3853 - val_accuracy: 0.8901 - val_loss: 0.3766
# Epoch 14/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8998 - loss: 0.3698 - val_accuracy: 0.8925 - val_loss: 0.3623
# Epoch 15/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.3493 - val_accuracy: 0.8986 - val_loss: 0.3488
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9169 - loss: 0.3424
# Test Accuracy with adagrad: 0.92
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91      1011
#            1       0.91      0.93      0.92      1059
#
#     accuracy                           0.92      2070
#    macro avg       0.92      0.92      0.92      2070
# weighted avg       0.92      0.92      0.92      2070
# Training with optimizer: rmsprop
# Epoch 1/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8428 - loss: 0.3871 - val_accuracy: 0.9976 - val_loss: 0.0479
# Epoch 2/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.0241 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 3/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 9.6013e-04
# Epoch 4/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.0532e-04 - val_accuracy: 1.0000 - val_loss: 3.2803e-04
# Epoch 5/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.5142e-04 - val_accuracy: 1.0000 - val_loss: 1.6339e-04
# Epoch 6/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 9.2098e-05 - val_accuracy: 1.0000 - val_loss: 1.0664e-04
# Epoch 7/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.9454e-05 - val_accuracy: 1.0000 - val_loss: 7.8210e-05
# Epoch 8/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.6555e-05 - val_accuracy: 1.0000 - val_loss: 6.1412e-05
# Epoch 9/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.0303e-05 - val_accuracy: 1.0000 - val_loss: 4.9179e-05
# Epoch 10/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.6450e-05 - val_accuracy: 1.0000 - val_loss: 4.1810e-05
# Epoch 11/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.1484e-05 - val_accuracy: 1.0000 - val_loss: 3.6273e-05
# Epoch 12/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.8521e-05 - val_accuracy: 1.0000 - val_loss: 3.2004e-05
# Epoch 13/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.6593e-05 - val_accuracy: 1.0000 - val_loss: 2.8568e-05
# Epoch 14/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.4305e-05 - val_accuracy: 1.0000 - val_loss: 2.5803e-05
# Epoch 15/15
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.4882e-05 - val_accuracy: 1.0000 - val_loss: 2.3520e-05
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.9256e-05
# Test Accuracy with rmsprop: 1.00
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1011
#            1       1.00      1.00      1.00      1059
#
#     accuracy                           1.00      2070
#    macro avg       1.00      1.00      1.00      2070
# weighted avg       1.00      1.00      1.00      2070
